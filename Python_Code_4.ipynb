# %% [markdown]
# Google_Ads data

# %%
import pandas as pd
df=pd.read_csv('Omnify_Analyst.csv')

# %%
df
# Out:
#           Week                        Campaign  \
# 0    25-Jan-21             EK_Generic_Swimming
# 1    25-Jan-21             EK_Generic_Swimming
# 2    25-Jan-21        EK_Generic_Quad-Tok_Yoga
# 3    25-Jan-21             EK_Generic_Swimming
# 4    25-Jan-21          EK_Generic_Swimming_UK
# ..         ...                             ...
# 413   3-May-21             EK_Generic_Swimming
# 414   3-May-21        EK_Generic_Quad-Tok_Yoga
# 415   3-May-21  EK_Generic_Tri-Tok_Reservation
# 416   3-May-21     EK_Generic_Quad-Tok_Pilates
# 417   3-May-21     EK_Generic_Quad-Tok_Pilates
#
#                                      Ad group Keywordtype  \
# 0               Pool_Reservation_System_Exact       Exact
# 1                      Pool_Booking_App_Exact       Exact
# 2          Yoga_Studio_Booking_Software_Broad       Broad
# 3             Pool_Scheduling_Software_Phrase      Phrase
# 4             Pool_Reservation_Software_Broad       Broad
# ...

# %%
df['Week'] = pd.to_datetime(df['Week'])
df = df.sort_values(by='Week')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))

# Clicks over time
plt.subplot(2, 2, 1)
plt.plot(df['Week'], df['Clicks'], marker='o')
plt.title('Clicks over Time')
plt.xlabel('Week')
plt.ylabel('Clicks')
plt.xticks(rotation=45)
# Out:
# (array([18659., 18673., 18687., 18701., 18718., 18732., 18748.]),
#  [Text(18659.0, 0, '2021-02-01'),
#   Text(18673.0, 0, '2021-02-15'),
#   Text(18687.0, 0, '2021-03-01'),
#   Text(18701.0, 0, '2021-03-15'),
#   Text(18718.0, 0, '2021-04-01'),
#   Text(18732.0, 0, '2021-04-15'),
#   Text(18748.0, 0, '2021-05-01')])

# %%
# Cost ($) over time
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
plt.plot(df['Week'], df['Cost'], marker='o', color='orange')
plt.title('Cost ($) over Time')
plt.xlabel('Week')
plt.ylabel('Cost ($)')
plt.xticks(rotation=45)
# Out:
# (array([18659., 18673., 18687., 18701., 18718., 18732., 18748.]),
#  [Text(18659.0, 0, '2021-02-01'),
#   Text(18673.0, 0, '2021-02-15'),
#   Text(18687.0, 0, '2021-03-01'),
#   Text(18701.0, 0, '2021-03-15'),
#   Text(18718.0, 0, '2021-04-01'),
#   Text(18732.0, 0, '2021-04-15'),
#   Text(18748.0, 0, '2021-05-01')])

# %%
# Leads over time
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 3)
plt.plot(df['Week'], df['Leads'], marker='o', color='green')
plt.title('Leads over Time')
plt.xlabel('Week')
plt.ylabel('Leads')
plt.xticks(rotation=45)
# Out:
# (array([18659., 18673., 18687., 18701., 18718., 18732., 18748.]),
#  [Text(18659.0, 0, '2021-02-01'),
#   Text(18673.0, 0, '2021-02-15'),
#   Text(18687.0, 0, '2021-03-01'),
#   Text(18701.0, 0, '2021-03-15'),
#   Text(18718.0, 0, '2021-04-01'),
#   Text(18732.0, 0, '2021-04-15'),
#   Text(18748.0, 0, '2021-05-01')])

# %%
df['Payment']=df['Payment'].str.replace('$','')
df['Payment']=df['Payment'].str.replace(',','')
df['Payment'] = pd.to_numeric(df['Payment'])

# %%
# Payment ($) over time
plt.subplot(2, 2, 4)
plt.plot(df['Week'], df['Payment'], marker='o', color='red')
plt.title('Payment ($) over Time')
plt.xlabel('Week')
plt.ylabel('Payment ($)')
plt.xticks(rotation=45)
# Out:
# (array([18659., 18673., 18687., 18701., 18718., 18732., 18748.]),
#  [Text(18659.0, 0, '2021-02-01'),
#   Text(18673.0, 0, '2021-02-15'),
#   Text(18687.0, 0, '2021-03-01'),
#   Text(18701.0, 0, '2021-03-15'),
#   Text(18718.0, 0, '2021-04-01'),
#   Text(18732.0, 0, '2021-04-15'),
#   Text(18748.0, 0, '2021-05-01')])

# %% [markdown]
# Listing_site data

# %%
import pandas as pd
df=pd.read_csv('Omnify_Analyst_1.csv')

# %%
df
# Out:
#      Product Name          Categories Date of Report  Average Position  \
# 0          Omnify            Coaching      20-Oct-20             13.00
# 1          Omnify        Dance Studio      20-Oct-20             20.00
# 2          Omnify    Personal Trainer      20-Oct-20              6.00
# 3          Omnify          Scheduling      20-Oct-20             59.00
# 4          Omnify  Class Registration      21-Oct-20              6.00
# ...           ...                 ...            ...               ...
# 2086       Omnify  Class Registration     04-30-2021             10.00
# 2087       Omnify     Club Management     04-30-2021              1.00
# 2088       Omnify            Coaching     04-30-2021             14.67
# 2089       Omnify        Dance Studio     04-30-2021              8.00
# 2090       Omnify             Fitness     04-30-2021              8.00
#
#       Clicks  Leads  MoneySpent          Channel        Location  Prospects  \
# ...

# %%
df['Date of Report'] = pd.to_datetime(df['Date of Report'])
time_series_data = df.groupby('Date of Report').agg({
    'Clicks': 'sum',
    'MoneySpent': 'sum'
}).reset_index()

# %%
plt.figure(figsize=(12, 6))
plt.plot(time_series_data['Date of Report'], time_series_data['Clicks'], marker='o', label='Clicks')
plt.plot(time_series_data['Date of Report'], time_series_data['MoneySpent'], marker='o', label='MoneySpent')
plt.title('Clicks and MoneySpent Over Time')
plt.xlabel('Date of Report')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
df['Paid']=df['Paid'].str.replace('$','')
df['Paid']=df['Paid'].str.replace(',','')
df['Paid'] = pd.to_numeric(df['Paid'])
# Out:
# C:\Users\SIVAPA~1\AppData\Local\Temp/ipykernel_11748/432958348.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Paid']=df['Paid'].str.replace('$','')

# %%
import seaborn as sns
df_payment_made = df[df['Paid'] > 0]
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Date of Report', y='Paid', hue='Location', size='Paid', data=df_payment_made, palette='viridis', sizes=(50, 200))
plt.title('Payments by Location over Time')
plt.xlabel('Date of Report')
plt.ylabel('Payment ($)')
plt.xticks(rotation=45)
plt.legend(title='Location')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Date of Report', y='Paid', hue='Categories', size='Paid', data=df_payment_made, palette='viridis', sizes=(50, 200))
plt.title('Payments by Category over Time')
plt.xlabel('Date of Report')
plt.ylabel('Payment ($)')
plt.xticks(rotation=45)
plt.legend(title='Categories')
plt.grid(True)
plt.show()
