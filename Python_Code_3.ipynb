# %%
import pandas as pd
df=pd.read_csv('Omnify_Analyst.csv')

# %%
df
# Out:
#           Week                        Campaign  \
# 0    25-Jan-21             EK_Generic_Swimming
# 1    25-Jan-21             EK_Generic_Swimming
# 2    25-Jan-21        EK_Generic_Quad-Tok_Yoga
# 3    25-Jan-21             EK_Generic_Swimming
# 4    25-Jan-21          EK_Generic_Swimming_UK
# ..         ...                             ...
# 413   3-May-21             EK_Generic_Swimming
# 414   3-May-21        EK_Generic_Quad-Tok_Yoga
# 415   3-May-21  EK_Generic_Tri-Tok_Reservation
# 416   3-May-21     EK_Generic_Quad-Tok_Pilates
# 417   3-May-21     EK_Generic_Quad-Tok_Pilates
#
#                                      Ad group Keywordtype  \
# 0               Pool_Reservation_System_Exact       Exact
# 1                      Pool_Booking_App_Exact       Exact
# 2          Yoga_Studio_Booking_Software_Broad       Broad
# 3             Pool_Scheduling_Software_Phrase      Phrase
# 4             Pool_Reservation_Software_Broad       Broad
# ...

# %%
df['Payment']=df['Payment'].str.replace('$','')
df['Payment']=df['Payment'].str.replace(',','')
df['Payment'] = pd.to_numeric(df['Payment'])
# Out:
# C:\Users\SIVAPA~1\AppData\Local\Temp/ipykernel_27352/4213942729.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Payment']=df['Payment'].str.replace('$','')

# %%
df
# Out:
#           Week                        Campaign  \
# 0    25-Jan-21             EK_Generic_Swimming
# 1    25-Jan-21             EK_Generic_Swimming
# 2    25-Jan-21        EK_Generic_Quad-Tok_Yoga
# 3    25-Jan-21             EK_Generic_Swimming
# 4    25-Jan-21          EK_Generic_Swimming_UK
# ..         ...                             ...
# 413   3-May-21             EK_Generic_Swimming
# 414   3-May-21        EK_Generic_Quad-Tok_Yoga
# 415   3-May-21  EK_Generic_Tri-Tok_Reservation
# 416   3-May-21     EK_Generic_Quad-Tok_Pilates
# 417   3-May-21     EK_Generic_Quad-Tok_Pilates
#
#                                      Ad group Keywordtype  \
# 0               Pool_Reservation_System_Exact       Exact
# 1                      Pool_Booking_App_Exact       Exact
# 2          Yoga_Studio_Booking_Software_Broad       Broad
# 3             Pool_Scheduling_Software_Phrase      Phrase
# 4             Pool_Reservation_Software_Broad       Broad
# ...

# %%
Amount_spent = df.pivot_table(index='Keywordtype', values='Cost', aggfunc='sum')
Amount_spent
# Out:
#                 Cost
# Keywordtype
# Broad        1264.80
# Exact         580.33
# Phrase        943.55

# %%
Amount_earned = df.pivot_table(index='Keywordtype', values='Payment', aggfunc='sum')
Amount_earned['profit']=Amount_earned['Payment']-Amount_spent['Cost']
Amount_earned
# Out:
#              Payment   profit
# Keywordtype
# Broad         5536.0  4271.20
# Exact         2768.0  2187.67
# Phrase        3576.0  2632.45

# %%
print("The Keyword with maximum profit is",Amount_earned['profit'].index.max())
# Out:
# The Keyword with maximum profit is Phrase
